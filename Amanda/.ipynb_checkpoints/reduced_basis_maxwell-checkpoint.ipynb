# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

from netgen.csg import *
from ngsolve import *
from ngsolve.webgui import Draw
# from netgen import gui
from ngsolve.comp import ConvertOperator
import numpy as np

import time

# %% [markdown]
# Geometrie: Spule mit Luftspalt und Stahlplatte dazwischen

# %%
geo = CSGeometry()
box_size = 2
box = OrthoBrick(Pnt(-box_size,-box_size,-box_size), Pnt(box_size,box_size,box_size)).bc("outer")

lx = 0.4
lz = 0.5
d = 0.1
lp = 0.3
core = OrthoBrick(Pnt(-lx,-d/2,-lz),Pnt(lx,d/2,lz))- \
           OrthoBrick(Pnt(d-lx,-d,-lz+d),Pnt(lx-d,d,lz-d))- \
           OrthoBrick(Pnt(d,-d,-d/2),Pnt(lx+d,d,d/2)).maxh(0.2).mat('core')

plate = OrthoBrick(Pnt(d/2,-lp,-d/4),Pnt(2*lx-d,lp,d/4)).maxh(0.05).mat('plate')


coil = (Cylinder(Pnt(-lx+d/2,0,0), Pnt(-lx+d/2,0,1), 3*d) - \
        Cylinder(Pnt(-lx+d/2,0,0), Pnt(-lx+d/2,0,1), d)) * \
        OrthoBrick (Pnt(-1,-1,-lz+2*d),Pnt(1,1,lz-2*d)).maxh(0.2).mat('coil')

air = (box - coil - plate -core).mat('air') 

geo.Add(plate)
geo.Add(core)
geo.Add(coil)
geo.Add(air, transparent=True)

mesh = Mesh(geo.GenerateMesh(maxh=0.5))
mesh.Curve(3)
Draw (mesh)


from matplotlib import pyplot as plt

H_KL = [ -4.47197834e-13, 1.60000000e+01, 3.00000000e+01, 5.40000000e+01\
, 9.30000000e+01, 1.43000000e+02, 1.91000000e+02, 2.10000000e+02 \
, 2.22000000e+02, 2.33000000e+02, 2.47000000e+02, 2.58000000e+02\
, 2.72000000e+02, 2.89000000e+02, 3.13000000e+02, 3.42000000e+02\
, 3.77000000e+02, 4.33000000e+02, 5.09000000e+02, 6.48000000e+02\
, 9.33000000e+02, 1.22800000e+03, 1.93400000e+03, 2.91300000e+03\
, 4.99300000e+03, 7.18900000e+03, 9.42300000e+03, 9.42300000e+03\
, 1.28203768e+04, 1.65447489e+04, 2.07163957e+04, 2.55500961e+04\
, 3.15206135e+04, 4.03204637e+04, 7.73038295e+04, 1.29272791e+05\
, 1.81241752e+05, 2.33210713e+05, 2.85179674e+05, 3.37148635e+05\
, 3.89117596e+05, 4.41086557e+05, 4.93055518e+05, 5.45024479e+05\
, 5.96993440e+05, 6.48962401e+05, 7.00931362e+05, 7.52900323e+05\
, 8.04869284e+05, 8.56838245e+05, 9.08807206e+05, 9.60776167e+05\
, 1.01274513e+06, 1.06471409e+06, 1.11668305e+06, 1.16865201e+06\
, 1.22062097e+06, 1.27258993e+06, 1.32455889e+06, 1.37652785e+06\
, 1.42849682e+06, 1.48046578e+06, 1.53243474e+06, 1.58440370e+06\
, 1.63637266e+06, 1.68834162e+06, 1.74031058e+06, 1.79227954e+06\
, 1.84424850e+06, 1.89621746e+06, 1.94818643e+06, 2.00015539e+06\
, 2.05212435e+06, 2.10409331e+06, 2.15606227e+06, 2.20803123e+06\
, 2.26000019e+06]

B_KL = [ 0.00000000e+00, 2.50000000e-03, 5.00000000e-03, 1.25000000e-02\
, 2.50000000e-02, 5.00000000e-02, 1.00000000e-01, 2.00000000e-01\
, 3.00000000e-01, 4.00000000e-01, 5.00000000e-01, 6.00000000e-01\
, 7.00000000e-01, 8.00000000e-01, 9.00000000e-01, 1.00000000e+00\
, 1.10000000e+00, 1.20000000e+00, 1.30000000e+00, 1.40000000e+00\
, 1.50000000e+00, 1.55000000e+00, 1.60000000e+00, 1.65000000e+00\
, 1.70000000e+00, 1.75000000e+00, 1.80000000e+00, 1.80000000e+00\
, 1.86530612e+00, 1.93061224e+00, 1.99591837e+00, 2.06122449e+00\
, 2.12653061e+00, 2.19183673e+00, 2.25714286e+00, 2.32244898e+00\
, 2.38775510e+00, 2.45306122e+00, 2.51836735e+00, 2.58367347e+00\
, 2.64897959e+00, 2.71428571e+00, 2.77959184e+00, 2.84489796e+00\
, 2.91020408e+00, 2.97551020e+00, 3.04081633e+00, 3.10612245e+00\
, 3.17142857e+00, 3.23673469e+00, 3.30204082e+00, 3.36734694e+00\
, 3.43265306e+00, 3.49795918e+00, 3.56326531e+00, 3.62857143e+00\
, 3.69387755e+00, 3.75918367e+00, 3.82448980e+00, 3.88979592e+00\
, 3.95510204e+00, 4.02040816e+00, 4.08571429e+00, 4.15102041e+00\
, 4.21632653e+00, 4.28163265e+00, 4.34693878e+00, 4.41224490e+00\
, 4.47755102e+00, 4.54285714e+00, 4.60816327e+00, 4.67346939e+00\
, 4.73877551e+00, 4.80408163e+00, 4.86938776e+00, 4.93469388e+00\
, 5.00000000e+00]
bh_curve = BSpline (2, [0]+list(B_KL), list(H_KL)) # [0] + is needed!
energy_dens = bh_curve.Integrate()
# help(energy_dens.Integrate())
# print(energy_dens) # wie plotten


plt.figure(1, figsize=[12, 9])
plt.clf()
plt.plot(H_KL, B_KL, '.-r')
plt.xlim(0, 2000)
plt.ylim(0, 2.12)
plt.grid()
plt.xlabel("Magnetic Field Strength H in A/m")
plt.ylabel("Magnetic Flux Density B in T")
# Out:
# NGSWebGuiWidget(value={'ngsolve_version': '6.2.2008-17-g2ebed44be', 'mesh_dim': 3, 'order2d': 2, 'order3d': 2,…
# Text(0, 0.5, 'Magnetic Flux Density B in T')

# %% [markdown]
# $$
# \DeclareMathOperator{\Grad}{grad}
# \DeclareMathOperator{\Curl}{curl}
# \DeclareMathOperator{\Div}{div}
# \DeclareMathOperator{\R}{\mathbb{R}}
# \DeclareMathOperator{\real}{real}
# \DeclareMathOperator{\reg}{reg}
# $$
# ### Magnetostatisches Problem ohne Stahlplatte
#
# Finde $ u \in H(\Curl)$ sodass
# $$
# \int \mu^{-1} \Curl u \Curl v + \reg \int  u  v= \int j v \qquad  \forall \, v \in H(\Curl) \tag{1}
# $$
#
# Wir nehmen zunächst an, dass der `core` aus einem tollen Material besteht das immer eine hohe, lineare Permeabilität hat. Um in den nichtlinearen Bereich des Stahls zu kommen wollen wir ein Magnetfeld zwischen 1.0 und 1.5 Tesla im Lufspalt.
#
# In folgender Rechnung wird vernachlässigt, dass der Luftspalt (bzw dann die zwei Luftspalte) kleiner ist wenn sich eine Stahlplatte darin befindet, daher ist das Ziel ohne Stahlplatte auf ca 1T zu kommen. Außerdem wird angenommen dass es keine Streuflüsse gibt.
#
# Es gilt für das Magnetfeld im Luftspalt $B_l$ gilt $B = \frac{\Phi}{A}$ Wobei $\Phi$ die magnetische Flussdichte und $A$ die Querschnittsfläche des Luftspalts ist. Die von der Spule erzeugte Durchflutung $\Theta$ beträgt $4d(l_z-d)*j$, falls die Stromdichte $j$ konstant ist.  Wenn wir die im Kern abfallende magnetische Spannung vernachlässigen gilt wegen $\Theta = R\Phi$ und des magnetische Widerstands im Luftspalt $R = \frac{d}{\mu_0A}$ dass
#
# $$
# 4d(l_z-d)j = \Theta = \frac{d}{\mu_0A}\Phi = \frac{d}{\mu_0}B.
# $$
#
# Die Stromdichte ergibt sich also ungefähr als
# $$
#  j \approx \frac{B}{4\mu_0(l_z-d) } \approx 5\cdot10^5.
# $$
#
# Es stellt sich heraus, dass $j \approx 7\cdot10^5$ zum gewünschten einen Tesla führt.
#
#
# ### Harmonische Magnetisierung
#
# Sei $j(x,t) = j(x)\cos(\omega t)$. Dann lautet das Problem
#
#
# Finde $ u \in C(\R^+; H(\Curl))$ sodass
# $$
# \int \frac{1}{\mu(|\Curl u|)}\Curl u \Curl v + \reg \int_{\Omega\setminus \text{plate}} u v + \sigma \int_{\text{plate}} \partial_t u v = \int j v \qquad  \forall \, v \in H(\Curl)
# $$
#
# Mit dem Funktional (3) ist das äquivalent zu: Finde ein $u\in H(\Curl)$ sodass
# $$
# \partial_v F(u) := \lim_{\epsilon \rightarrow 0} \frac{d}{d\epsilon} F(u+\epsilon v) = -\sigma \int_{\text{plate}} \partial_t u v \qquad \forall v \in H(\Curl)
# $$
#
# Impliziter Euler:
# $$
# \partial_v F(u^{n+1}) = -\sigma \int_{\text{plate}} \frac{u^{n+1} - u^{n}}{\Delta t}v \qquad \forall v \in H(\Curl)
# $$
#
# Die Lösung dieser Gleichung ist äquivalent zur Minimierung des Funktionals
#
# $$
# G(u) = F(u)+\frac{\sigma}{2\Delta t }\int_{\text{plate}} (u-u^n)^2
# $$
#
# wobei $u^{n+1} := u$.

# %%
fes = HCurl(mesh, order = 3, dirichlet="outer", nograds=True)
u = fes.TrialFunction()
from math import pi

mu0 = 4*pi*1e-7
mur = { "core" : 1e10, "coil" : 1, "air" : 1}
sigma = {'plate': 8.6*1e6}
omega = 2*np.pi*30 # angular frequency
dt = 5e-3


t = Parameter(1)
j = CoefficientFunction((-y,lx-d/2+x,0))*CoefficientFunction(-1/sqrt(y**2+(lx-d/2+x)**2)*cos(t*omega)*1e5)

gfu = GridFunction(fes)
gfu_old = GridFunction(fes)

a = BilinearForm(fes)
for mat in mur.keys():
    a += Variation( 1/(2*mu0*mur[mat])*curl(u)*curl(u)*dx(mat) + 1e-6*1/(2*mu0*mur[mat])*u*u*dx(mat))
a += Variation(energy_dens(sqrt(1e-12+ curl(u)*curl(u))) * dx('plate'))
a += Variation(sigma['plate']/(2*dt)*(u-gfu_old)**2*dx('plate'))
a += Variation(j*u*dx('coil'))
    
## TODO: hier Abwandlung des preconditioning Beispiels
c = Preconditioner(a, "bddc")

# %%
import logging
from datetime import datetime

logging.basicConfig(filename='output/nonlinear_{}.log'.format(datetime.now().strftime("%d-%b-%Y (%H:%M:%S)")),level=logging.DEBUG)

TOL = 1e-8
MAX_IT = 30
MAX_STEPS = int(0.5/dt)
pnt = mesh(lx-d/2, 0, 0)

logging.info("""
TOL = {}
MAX_IT = {}
MAX_STEPS = {}
dt = {}
eval point = {}
angluar frequency = {}
""".format(TOL, MAX_IT, MAX_STEPS, dt, (lx-d/2, 0, 0), omega))


values = [None]*int(1/dt)
# achtung [np.zeros(MAX_STEPS)]*3 geht nicht weil Referenz auf gleiches Objekt
plot_data = {'B': [np.zeros(MAX_STEPS) for _ in range(3)], 
             'A': [np.zeros(MAX_STEPS) for _ in range(3)],
             'E': [np.zeros(MAX_STEPS) for _ in range(3)]} 



with TaskManager():

    res = gfu.vec.CreateVector()
    w = gfu.vec.CreateVector()
    tmp = gfu.vec.CreateVector()
    
#     gfu.Set((sin(x),0,0)) # betragsmäßig zu große Anfangsdaten sind ein Problem!
    gfu.vec[:] = 0
    
    for step in range(MAX_STEPS):
        print("\nImplicit Euler Iteration: {}\n".format(step))
        logging.info("\nImplicit Euler Iteration: {}\n".format(step))
        
        
        gfu_old.vec.data = gfu.vec

    
        ####### begin solve problem

        err = 1
        it = 0

        while err > TOL and it < MAX_IT:
            it += 1

            e_old = a.Energy(gfu.vec)

            a.Apply(gfu.vec, res)

            a.AssembleLinearization(gfu.vec)
            solvers.CG(sol=w, rhs=res, mat=a.mat, pre=c.mat, printrates=False)

            err = abs(InnerProduct(w, res))

            print(" error {} in newton iteration {}".format(err, it))
            logging.info(" error {} in newton iteration {}".format(err, it))

            tmp.data = gfu.vec - w

            e_new = a.Energy(tmp)
#             print(" old energy: {}, new energy: {}".format(e_old, e_new))

            tau = 1
            cnt = 1
            while e_new > e_old:
                tau *= max(0.1, 1-0.1*cnt)
                cnt += 1
                tmp.data = gfu.vec - tau*w
                e_new = a.Energy(tmp)
#                 print(" new energy: {} with tau: {}".format( e_new, tau))

            gfu.vec.data = tmp

        index = int(step % (1/dt))
        if (values[index]):
            print("B({}): {}\nB({}-1): {}".format(step*dt, values[index], step*dt, curl(gfu)(pnt)))
            logging.info("B({}): {}\nB({}-1): {}".format(step*dt, values[index], step*dt, curl(gfu)(pnt)))

        else:
            print("B({}): {}".format(step*dt, curl(gfu)(pnt)))
            logging.info("B({}): {}".format(step*dt, curl(gfu)(pnt)))

        values[index] = curl(gfu)(pnt)
        
        for i in range(3):
            plot_data['B'][i][step] = curl(gfu)(pnt)[i]
            plot_data['A'][i][step] = gfu(pnt)[i]
            plot_data['E'][i][step] = ((gfu-gfu_old)/dt)(pnt)[i]

        ####### end solve problem
    
        t.Set(t.Get()+dt)

def show():
    Draw (curl(gfu), mesh, "B-field", draw_surf=False)
    Draw ((gfu-gfu_old)/dt, mesh, "E-field", draw_surf=False)
    mip = mesh(lx-d/2, 0, 0)
    print(curl(gfu)(mip), np.linalg.norm(curl(gfu)(mip)))
# Out:
# Implicit Euler Iteration: 0
#
#  error 313.24646346467506 in newton iteration 1
#  error 0.49236044029513254 in newton iteration 2
#  error 4.912352369682702e-05 in newton iteration 3
#  error 9.160447674472967e-08 in newton iteration 4
#  error 5.794033801281391e-17 in newton iteration 5
# B(0.0): (0.0009618036662012042, -0.022035551254764113, -0.013623040756490911)
#
# Implicit Euler Iteration: 1
#
#  error 50.154172942481175 in newton iteration 1
#  error 4.482639602528647e-06 in newton iteration 2
#  error 9.173809203142183e-13 in newton iteration 3
# B(0.005): (0.00123987753843523, -0.027897797524452927, -0.016960543636574347)
#
# Implicit Euler Iteration: 2
#
#  error 246.2599733126632 in newton iteration 1
#  error 0.007045849952549699 in newton iteration 2
#  error 4.995889366372696e-06 in newton iteration 3
#  error 3.2414254994897605e-10 in newton iteration 4
# B(0.01): (0.0004494213522232512, -0.009676430814057025, -0.005460725649451989)
#
# Implicit Euler Iteration: 3
#
#  error 158.38373141292885 in newton iteration 1
#  error 0.023263615565114037 in newton iteration 2
#  error 2.2443986276537407e-07 in newton iteration 3
#  error 3.8066798066772164e-14 in newton iteration 4
# B(0.015): (-0.0007654204475364356, 0.01686805639801183, 0.010871261531376774)
#
# Implicit Euler Iteration: 4
#
#  error 17.138546490272127 in newton iteration 1
#  error 0.0015750863174446754 in newton iteration 2
#  error 4.243035875096013e-06 in newton iteration 3
#  error 2.700527817646137e-10 in newton iteration 4
# B(0.02): (-0.0014351676834951736, 0.03165402308657632, 0.01968976964833382)
#
# Implicit Euler Iteration: 5
#
#  error 191.8244116340327 in newton iteration 1
#  error 0.007584795348148222 in newton iteration 2
#  error 1.2072426131006505e-06 in newton iteration 3
#  error 1.4232937862056434e-13 in newton iteration 4
# B(0.025): (-0.0009938599140760522, 0.02133739030600668, 0.012860040369681693)
#
# Implicit Euler Iteration: 6
#
#  error 224.22676454007734 in newton iteration 1
#  error 0.03857476054660517 in newton iteration 2
#  error 5.385531464907054e-06 in newton iteration 3
#  error 3.314665051731453e-12 in newton iteration 4
# B(0.03): (0.00020820337737918393, -0.004359145211447071, -0.003180543727125172)
#
# Implicit Euler Iteration: 7
#
#  error 28.554665654440825 in newton iteration 1
#  error 0.01122752115656115 in newton iteration 2
#  error 6.1812768418872295e-06 in newton iteration 3
#  error 5.059718017310046e-12 in newton iteration 4
# B(0.035): (0.001176514688290106, -0.0253241736731821, -0.016024009124526964)
#
# Implicit Euler Iteration: 8
#
#  error 117.54865802381711 in newton iteration 1
#  error 0.0014178757459270708 in newton iteration 2
#  error 1.7810498044260112e-06 in newton iteration 3
#  error 1.684871297848032e-14 in newton iteration 4
# B(0.04): (0.0011343097262810217, -0.023720366203891844, -0.014716277640916726)
#
# Implicit Euler Iteration: 9
#
#  error 258.0453082292732 in newton iteration 1
#  error 0.011079925678213393 in newton iteration 2
#  error 3.3842114559385823e-06 in newton iteration 3
#  error 8.393262193247252e-11 in newton iteration 4
# B(0.045): (8.306902165127313e-05, -0.0008338486767035557, -0.0004560439670622771)
#
# Implicit Euler Iteration: 10
#
#  error 81.6874489710091 in newton iteration 1
#  error 0.05830777780878266 in newton iteration 2
#  error 1.4046447376225358e-06 in newton iteration 3
#  error 1.662228751498365e-14 in newton iteration 4
# B(0.05): (-0.001037165664643799, 0.02385620308737662, 0.014678143661289453)
#
# Implicit Euler Iteration: 11
#
#  error 50.689951253124434 in newton iteration 1
#  error 4.50188607240396e-06 in newton iteration 2
#  error 8.821874563240052e-14 in newton iteration 3
# B(0.055): (-0.0013448363242954966, 0.030639008003242374, 0.01850059693960643)
#
# Implicit Euler Iteration: 12
#
#  error 245.59676077679273 in newton iteration 1
#  error 0.006659002883234815 in newton iteration 2
#  error 3.512681982826812e-06 in newton iteration 3
#  error 7.355407190810604e-11 in newton iteration 4
# B(0.06): (-0.000558573942548683, 0.012689338107251499, 0.007046168619261701)
#
# Implicit Euler Iteration: 13
#
#  error 157.61937571068015 in newton iteration 1
#  error 0.026628058162341192 in newton iteration 2
#  error 3.72971033744685e-07 in newton iteration 3
#  error 1.4321898645238933e-13 in newton iteration 4
# B(0.065): (0.0006670831463470365, -0.013794544600006625, -0.009361595719050342)
#
# Implicit Euler Iteration: 14
#
#  error 16.834722298720266 in newton iteration 1
#  error 0.0012020653574155427 in newton iteration 2
#  error 6.085383911738825e-06 in newton iteration 3
#  error 1.4847862596009484e-13 in newton iteration 4
# B(0.07): (0.0013493059022445877, -0.0285516785055928, -0.01823802143442654)
#
# Implicit Euler Iteration: 15
#
#  error 191.95781110226423 in newton iteration 1
#  error 0.007967418756377253 in newton iteration 2
#  error 1.4440319322733636e-06 in newton iteration 3
#  error 8.395516829296762e-13 in newton iteration 4
# B(0.075): (0.0009248205941136886, -0.01835632095122752, -0.011577567021297565)
#
# Implicit Euler Iteration: 16
#
#  error 224.46006755488557 in newton iteration 1
#  error 0.037437423533183446 in newton iteration 2
#  error 3.3004249793317077e-06 in newton iteration 3
#  error 2.2261095273524716e-12 in newton iteration 4
# B(0.08): (-0.00024473122759332194, 0.007052869588251739, 0.004189230469911927)
#
# Implicit Euler Iteration: 17
#
#  error 28.722842319395845 in newton iteration 1
#  error 0.008983231668390936 in newton iteration 2
#  error 4.8428077387285326e-06 in newton iteration 3
#  error 6.613171821327854e-12 in newton iteration 4
# B(0.085): (-0.0011968703168065795, 0.027907804987016598, 0.016900597257482195)
#
# Implicit Euler Iteration: 18
#
#  error 117.54264770357413 in newton iteration 1
#  error 0.001327402070221338 in newton iteration 2
#  error 1.4024428448693407e-06 in newton iteration 3
#  error 8.981609673496708e-15 in newton iteration 4
# B(0.09): (-0.0011379331954270867, 0.0261724997262352, 0.0154505442372092)
#
# Implicit Euler Iteration: 19
#
#  error 257.9781718224512 in newton iteration 1
#  error 0.008988428138940793 in newton iteration 2
#  error 3.5839737653114404e-06 in newton iteration 3
#  error 3.2148745861661244e-10 in newton iteration 4
# B(0.095): (-9.099478763461537e-05, 0.002899690260693879, 0.0008419963435965483)
#
# Implicit Euler Iteration: 20
#
#  error 81.78920670323774 in newton iteration 1
#  error 0.04601168568665521 in newton iteration 2
#  error 1.926205668607697e-06 in newton iteration 3
#  error 7.706740172979711e-14 in newton iteration 4
# B(0.1): (0.001048058227000064, -0.021902692925326546, -0.01439507732759268)
#
# Implicit Euler Iteration: 21
#
#  error 50.674003780787274 in newton iteration 1
#  error 4.550345745405823e-06 in newton iteration 2
#  error 2.614390620268056e-13 in newton iteration 3
# B(0.105): (0.0013645288983076757, -0.028783870604720752, -0.018303733965924225)
#
# Implicit Euler Iteration: 22
#
#  error 245.62197149325903 in newton iteration 1
#  error 0.006822700800703576 in newton iteration 2
#  error 4.230203136268902e-06 in newton iteration 3
#  error 9.055929576791564e-10 in newton iteration 4
# B(0.11): (0.0005818289399687101, -0.01099572923170787, -0.006980445402041007)
#
# Implicit Euler Iteration: 23
#
#  error 157.5965394355615 in newton iteration 1
#  error 0.02285139071470962 in newton iteration 2
#  error 2.224626466420676e-07 in newton iteration 3
#  error 1.8224779941592497e-14 in newton iteration 4
# B(0.115): (-0.0006377791728553923, 0.015351985923700271, 0.009325589127619962)
#
# Implicit Euler Iteration: 24
#
#  error 16.849412162544848 in newton iteration 1
#  error 0.0012622869553878687 in newton iteration 2
#  error 5.7076958426251226e-06 in newton iteration 3
#  error 1.0217102343947517e-11 in newton iteration 4
# B(0.12): (-0.0013142427413189884, 0.030025003339954635, 0.01813690326371933)
#
# Implicit Euler Iteration: 25
#
#  error 191.95238178330064 in newton iteration 1
#  error 0.007870933786527519 in newton iteration 2
#  error 1.4054011491728802e-06 in newton iteration 3
#  error 9.757777592843261e-13 in newton iteration 4
# B(0.125): (-0.0008857213889469857, 0.0197182207813761, 0.011395022011720568)
#
# Implicit Euler Iteration: 26
#
#  error 224.46112286491172 in newton iteration 1
#  error 0.03794400507052771 in newton iteration 2
#  error 4.492090057289757e-06 in newton iteration 3
#  error 7.004307129402696e-12 in newton iteration 4
# B(0.13): (0.00029095209197135417, -0.005852601110267977, -0.004471354129727102)
#
# Implicit Euler Iteration: 27
#  error 28.683017321474868 in newton iteration 1
#  error 0.011149070669086252 in newton iteration 2
#  error 5.09005653767599e-06 in newton iteration 3
#  error 2.053898878678143e-13 in newton iteration 4
# B(0.135): (0.0012450525382237158, -0.026768476857254957, -0.01722337512483282)
#
# Implicit Euler Iteration: 28
#
#  error 117.5427851774918 in newton iteration 1
#  error 0.0013432674237203062 in newton iteration 2
#  error 1.4848483569849352e-06 in newton iteration 3
#  error 1.280606982419553e-14 in newton iteration 4
# B(0.14): (0.0011875246989231914, -0.025094989284885107, -0.015814092216486744)
#
# Implicit Euler Iteration: 29
#
#  error 257.9817079336037 in newton iteration 1
#  error 0.010566141596762042 in newton iteration 2
#  error 4.0725609663392425e-06 in newton iteration 3
#  error 5.456864932759349e-11 in newton iteration 4
# B(0.145): (0.00012877528493562428, -0.0019988476436203556, -0.0013331615162784421)
#
# Implicit Euler Iteration: 30
#
#  error 81.66787617955521 in newton iteration 1
#  error 0.055230536224944754 in newton iteration 2
#  error 1.9691046335204235e-06 in newton iteration 3
#  error 4.2051976675401647e-14 in newton iteration 4
# B(0.15): (-0.0010062597296255458, 0.02275796160693943, 0.013882637311428683)
#
# Implicit Euler Iteration: 31
#
#  error 50.67913755378874 in newton iteration 1
#  error 4.193185288569136e-06 in newton iteration 2
#  error 7.122021744434558e-13 in newton iteration 3
# B(0.155): (-0.0013244314241553843, 0.02959930443657167, 0.01777194321491639)
#
# Implicit Euler Iteration: 32
#
#  error 245.6138510275 in newton iteration 1
#  error 0.006745860923589073 in newton iteration 2
#  error 3.900910939049011e-06 in newton iteration 3
#  error 2.2354267062109858e-10 in newton iteration 4
# B(0.16): (-0.0005492555496600951, 0.011742882350036937, 0.00641239371917605)
#
# Implicit Euler Iteration: 33
#
#  error 157.62628787335103 in newton iteration 1
#  error 0.02542566224115764 in newton iteration 2
#  error 3.12665843211338e-07 in newton iteration 3
#  error 1.530932547379676e-14 in newton iteration 4
# B(0.165): (0.0006675232306822312, -0.014660292104900519, -0.009918115222373044)
#
# Implicit Euler Iteration: 34
#
#  error 16.84300382277122 in newton iteration 1
#  error 0.0012525330912193302 in newton iteration 2
#  error 5.7889216163080195e-06 in newton iteration 3
#  error 1.373814660731662e-13 in newton iteration 4
# B(0.17): (0.0013424122335314503, -0.02936497135596374, -0.018741239258357467)
#
# Implicit Euler Iteration: 35
#
#  error 191.9545948983099 in newton iteration 1
#  error 0.007884811591380322 in newton iteration 2
#  error 1.4145174482358338e-06 in newton iteration 3
#  error 1.2593854584572405e-12 in newton iteration 4
# B(0.17500000000000002): (0.0009110696128071526, -0.019101776767651613, -0.012018494250598715)
#
# Implicit Euler Iteration: 36
#
#  error 224.4573726943308 in newton iteration 1
#  error 0.03781132818192826 in newton iteration 2
#  error 3.537571927724877e-06 in newton iteration 3
#  error 1.982991164529231e-12 in newton iteration 4
# B(0.18): (-0.0002649788528075599, 0.006389121762470608, 0.003812079585719072)
#
# Implicit Euler Iteration: 37
#
#  error 28.71245897895858 in newton iteration 1
#  error 0.009423990464010183 in newton iteration 2
#  error 4.98029610435619e-06 in newton iteration 3
#  error 2.031134917676548e-13 in newton iteration 4
# B(0.185): (-0.0012214562230849846, 0.027284522421851143, 0.016562390645931804)
#
# Implicit Euler Iteration: 38
#
#  error 117.54267330626894 in newton iteration 1
#  error 0.0013403663746167395 in newton iteration 2
#  error 1.4462511231081291e-06 in newton iteration 3
#  error 9.807524814366866e-15 in newton iteration 4
# B(0.19): (-0.001166227527521595, 0.02559008868224759, 0.015151268839204517)
#
# Implicit Euler Iteration: 39
#
#  error 257.97975186129156 in newton iteration 1
#  error 0.009366102874998936 in newton iteration 2
#  error 3.4910170663958413e-06 in newton iteration 3
#  error 2.37823832164584e-10 in newton iteration 4
# B(0.195): (-0.00011723895678365237, 0.002409920481492321, 0.0006207440879061865)
#
# Implicit Euler Iteration: 40
#
#  error 81.76616518844617 in newton iteration 1
#  error 0.04801893655116603 in newton iteration 2
#  error 1.8769728084201777e-06 in newton iteration 3
#  error 4.073329322028495e-14 in newton iteration 4
# B(0.2): (0.001018686388407161, -0.022361554951734877, -0.014590388845352043)
#
# Implicit Euler Iteration: 41
#
#  error 50.67537696158324 in newton iteration 1
#  error 4.517725024166441e-06 in newton iteration 2
#  error 4.360770962498206e-13 in newton iteration 3
# B(0.20500000000000002): (0.0013333511491024376, -0.029215544891103715, -0.018476235471925978)
#
# Implicit Euler Iteration: 42
#
#  error 245.62025156798117 in newton iteration 1
#  error 0.006795869501928365 in newton iteration 2
#  error 4.021823882151076e-06 in newton iteration 3
#  error 6.131879108911547e-10 in newton iteration 4
# B(0.21): (0.0005512906444785657, -0.011388395321463846, -0.0071280361002827655)
#
# Implicit Euler Iteration: 43
#
#  error 157.60281657435235 in newton iteration 1
#  error 0.023518058942460604 in newton iteration 2
#  error 2.399140640864022e-07 in newton iteration 3
#  error 1.670355109710798e-14 in newton iteration 4
# B(0.215): (-0.0006677254394641438, 0.014991123125468414, 0.009200654293843783)
#
# Implicit Euler Iteration: 44
#
#  error 16.847832188065432 in newton iteration 1
#  error 0.0012543238287297722 in newton iteration 2
#  error 5.748695441389852e-06 in newton iteration 3
#  error 1.916776888308857e-11 in newton iteration 4
# B(0.22): (-0.0013448210083672747, 0.029683653032915713, 0.01802671812302143)
#
# Implicit Euler Iteration: 45
#
#  error 191.95302814795934 in newton iteration 1
#  error 0.0078506534153267 in newton iteration 2
#  error 1.390682895866922e-06 in newton iteration 3
#  error 7.64596174614974e-13 in newton iteration 4
# B(0.225): (-0.000916082650304861, 0.019401437055620384, 0.011302368358376056)
#
# Implicit Euler Iteration: 46
#
#  error 224.46032482006302 in newton iteration 1
#  error 0.037841486826250194 in newton iteration 2
#  error 4.127363506913614e-06 in newton iteration 3
#  error 3.888964682682641e-12 in newton iteration 4
# B(0.23): (0.00026165791172556873, -0.006134148613464181, -0.004544489015282825)
#
# Implicit Euler Iteration: 47
#
#  error 28.68825402700848 in newton iteration 1
#  error 0.010783526487445962 in newton iteration 2
#  error 5.069352320161736e-06 in newton iteration 3
#  error 2.0766472482098436e-13 in newton iteration 4
# B(0.23500000000000001): (0.0012161685357569675, -0.027034826158358647, -0.01728553059146092)
#
# Implicit Euler Iteration: 48
#
#  error 117.54282013428497 in newton iteration 1
#  error 0.001340311773187296 in newton iteration 2
#  error 1.4753336267548121e-06 in newton iteration 3
#  error 1.0398954453517356e-14 in newton iteration 4
# B(0.24): (0.0011588158578871542, -0.02534608903056423, -0.015865308812745588)
#
# Implicit Euler Iteration: 49
#
#  error 257.9815751381213 in newton iteration 1
#  error 0.010326316329120963 in newton iteration 2
#  error 3.958293770961037e-06 in newton iteration 3
#  error 1.4987058016164305e-10 in newton iteration 4
# B(0.245): (0.0001050678175956417, -0.0022109189719666518, -0.0013578133997795216)
#
# Implicit Euler Iteration: 50
#
#  error 81.68263186587309 in newton iteration 1
#  error 0.053508832194002834 in newton iteration 2
#  error 1.9543017706376086e-06 in newton iteration 3
#  error 3.1027554972759396e-14 in newton iteration 4
# B(0.25): (-0.0010298063238170885, 0.022557140407807236, 0.013864389651339033)
#
# Implicit Euler Iteration: 51
#
#  error 50.67835623061043 in newton iteration 1
#  error 4.185838046277926e-06 in newton iteration 2
#  error 7.776587497352402e-13 in newton iteration 3
# B(0.255): (-0.0013470351919929692, 0.02940854639935501, 0.017759692838806504)
#
# Implicit Euler Iteration: 52
#
#  error 245.61504049743223 in newton iteration 1
#  error 0.0067430325378428305 in newton iteration 2
#  error 3.967163914799975e-06 in newton iteration 3
#  error 2.4501174574326447e-10 in newton iteration 4
# B(0.26): (-0.0005694978092617571, 0.011567662730580297, 0.0064087738704853995)
#
# Implicit Euler Iteration: 53
#
#  error 157.62259750555646 in newton iteration 1
#  error 0.024989486591463154 in newton iteration 2
#  error 2.9699010934509534e-07 in newton iteration 3
#  error 9.902740764992818e-14 in newton iteration 4
# B(0.265): (0.0006492318253314722, -0.014823006333489657, -0.009916654537608543)
#
# Implicit Euler Iteration: 54
#  error 16.84388077405676 in newton iteration 1
#  error 0.0012523037660942676 in newton iteration 2
#  error 5.776375078386538e-06 in newton iteration 3
#  error 6.668514504983088e-13 in newton iteration 4
# B(0.27): (0.0013252734258701175, -0.029520134567900754, -0.01873626838107923)
#
# Implicit Euler Iteration: 55
#
#  error 191.9543443337031 in newton iteration 1
#  error 0.007879401579743631 in newton iteration 2
#  error 1.4037657458662555e-06 in newton iteration 3
#  error 1.0754975609036273e-12 in newton iteration 4
# B(0.275): (0.0008956948036527289, -0.019246682945827022, -0.012009033931576197)
#
# Implicit Euler Iteration: 56
#
#  error 224.45823911961267 in newton iteration 1
#  error 0.0379111128158707 in newton iteration 2
#  error 3.640554187860065e-06 in newton iteration 3
#  error 2.9366352381568363e-12 in newton iteration 4
# B(0.28): (-0.0002780935662757682, 0.006259147554767202, 0.0038265833080674033)
#
# Implicit Euler Iteration: 57
#
#  error 28.70921458129665 in newton iteration 1
#  error 0.00963159145945916 in newton iteration 2
#  error 4.991584684217364e-06 in newton iteration 3
#  error 2.0378574619716916e-13 in newton iteration 4
# B(0.28500000000000003): (-0.0012335986572080744, 0.027160345886914055, 0.016579274073291458)
#
# Implicit Euler Iteration: 58
#
#  error 117.5426601673749 in newton iteration 1
#  error 0.0013415315800839075 in newton iteration 2
#  error 1.4515787004722501e-06 in newton iteration 3
#  error 4.5369441071960433e-13 in newton iteration 4
# B(0.29): (-0.0011773388388143177, 0.025471892503430155, 0.015170781512529317)
#
# Implicit Euler Iteration: 59
#
#  error 257.98010248907946 in newton iteration 1
#  error 0.00953495215335651 in newton iteration 2
#  error 3.4848505114735766e-06 in newton iteration 3
#  error 2.2488153640645371e-10 in newton iteration 4
# B(0.295): (-0.00012463012098208517, 0.002309323147649469, 0.0006502805133899713)
#
# Implicit Euler Iteration: 60
#
#  error 81.75563964632231 in newton iteration 1
#  error 0.04897222737658172 in newton iteration 2
#  error 1.882497411572243e-06 in newton iteration 3
#  error 1.1769440396207095e-13 in newton iteration 4
# B(0.3): (0.0010115838809667376, -0.022457838621962257, -0.01456024515651545)
#
# Implicit Euler Iteration: 61
#
#  error 50.67585114221903 in newton iteration 1
#  error 4.413979229754901e-06 in newton iteration 2
#  error 7.435846088193615e-13 in newton iteration 3
# B(0.305): (0.0013270811096064248, -0.02930785390570734, -0.018445185012724467)
#
# Implicit Euler Iteration: 62
#
#  error 245.61964781745462 in newton iteration 1
#  error 0.006780223710212072 in newton iteration 2
#  error 3.972332480364867e-06 in newton iteration 3
#  error 5.200180186971776e-10 in newton iteration 4
# B(0.31): (0.0005466004799089879, -0.011473924748052118, -0.007094806921088377)
#
# Implicit Euler Iteration: 63
#
#  error 157.60592957842837 in newton iteration 1
#  error 0.02381369958501953 in newton iteration 2
#  error 2.351700243872453e-07 in newton iteration 3
#  error 1.3002214084120486e-15 in newton iteration 4
# B(0.315): (-0.0006711080501914105, 0.014910857128933983, 0.009234348860657432)
#
# Implicit Euler Iteration: 64
#
#  error 16.847162891262325 in newton iteration 1
#  error 0.0012554337975717554 in newton iteration 2
#  error 5.756994319236375e-06 in newton iteration 3
#  error 1.2934763576393533e-13 in newton iteration 4
# B(0.32): (-0.0013474850768528588, 0.0296065807909469, 0.018060860179097905)
#
# Implicit Euler Iteration: 65
#
#  error 191.9532180496039 in newton iteration 1
#  error 0.007854141934354384 in newton iteration 2
#  error 1.3924997740655894e-06 in newton iteration 3
#  error 7.683841600930681e-13 in newton iteration 4
# B(0.325): (-0.0009175651211788039, 0.019328537122254574, 0.011336879253801849)
#
# Implicit Euler Iteration: 66
#
#  error 224.46007787014136 in newton iteration 1
#  error 0.03784561589982115 in newton iteration 2
#  error 4.095299276994547e-06 in newton iteration 3
#  error 4.7295365732920805e-12 in newton iteration 4
# B(0.33): (0.0002612373795204811, -0.006199141082816098, -0.004508169551228508)
#
# Implicit Euler Iteration: 67
#
#  error 28.691145618293774 in newton iteration 1
#  error 0.010592871656176206 in newton iteration 2
#  error 5.057709372595791e-06 in newton iteration 3
#  error 2.0662203160807034e-13 in newton iteration 4
# B(0.335): (0.0012163039097369181, -0.027097539165168705, -0.017249380384153364)
#
# Implicit Euler Iteration: 68
#
#  error 117.5428252688862 in newton iteration 1
#  error 0.0013397514969980691 in newton iteration 2
#  error 1.472958713742203e-06 in newton iteration 3
#  error 1.0325445019960527e-14 in newton iteration 4
# B(0.34): (0.0011593679050936711, -0.025406491965061843, -0.01582930046344033)
#
# Implicit Euler Iteration: 69
#
#  error 257.9814134240408 in newton iteration 1
#  error 0.010210855204153066 in newton iteration 2
#  error 3.838370688463213e-06 in newton iteration 3
#  error 4.008302341434216e-10 in newton iteration 4
# B(0.34500000000000003): (0.00010750137180609207, -0.0022624032642895127, -0.0013178553171085208)
#
# Implicit Euler Iteration: 70
#
#  error 81.69115718470844 in newton iteration 1
#  error 0.052653597110050035 in newton iteration 2
#  error 1.9136990347263075e-06 in newton iteration 3
#  error 4.614175337043437e-13 in newton iteration 4
# B(0.35000000000000003): (-0.0010273072883067924, 0.022507283765516868, 0.01390342020347012)
#
# Implicit Euler Iteration: 71
#
#  error 50.67801597700098 in newton iteration 1
#  error 4.233789048353036e-06 in newton iteration 2
#  error 9.788523885583291e-13 in newton iteration 3
# B(0.355): (-0.001344050177820333, 0.029360218299104474, 0.017798164767390573)
#
# Implicit Euler Iteration: 72
#
#  error 245.61549644382282 in newton iteration 1
#  error 0.006752530558543094 in newton iteration 2
#  error 3.995807635836266e-06 in newton iteration 3
#  error 2.709468045689535e-10 in newton iteration 4
# B(0.36): (-0.0005655357869891513, 0.011522506842591368, 0.006447483439202722)
#
# Implicit Euler Iteration: 73
#
#  error 157.62000238931205 in newton iteration 1
#  error 0.024779091358603785 in newton iteration 2
#  error 2.7964855864663173e-07 in newton iteration 3
#  error 1.0585129440380084e-14 in newton iteration 4
# B(0.365): (0.0006537203826899299, -0.0148657665568994, -0.009878766248875789)
#
# Implicit Euler Iteration: 74
#
#  error 16.84430641050708 in newton iteration 1
#  error 0.0012525075764745828 in newton iteration 2
#  error 5.771309159724653e-06 in newton iteration 3
#  error 1.6029386253584965e-13 in newton iteration 4
# B(0.37): (0.001330122323449646, -0.029561533910556596, -0.018698908320832954)
#
# Implicit Euler Iteration: 75
#
#  error 191.95421233506832 in newton iteration 1
#  error 0.007876683216842996 in newton iteration 2
#  error 1.4014733897169075e-06 in newton iteration 3
#  error 1.0373370881011915e-12 in newton iteration 4
# B(0.375): (0.0009010372604964764, -0.019286015322784945, -0.011972103726622427)
#
# Implicit Euler Iteration: 76
#
#  error 224.45843864160676 in newton iteration 1
#  error 0.037925222088158836 in newton iteration 2
#  error 3.706631790159742e-06 in newton iteration 3
#  error 2.365245957991842e-12 in newton iteration 4
# B(0.38): (-0.000272274902105451, 0.006223813628175253, 0.0038637366756055346)
#
# Implicit Euler Iteration: 77
#
#  error 28.707234184336475 in newton iteration 1
#  error 0.009741402849135718 in newton iteration 2
#  error 4.995677615497799e-06 in newton iteration 3
#  error 2.0317884503724943e-13 in newton iteration 4
# B(0.385): (-0.0012275888920412223, 0.02712589759550796, 0.016615608730989488)
#
# Implicit Euler Iteration: 78
#
#  error 117.54266055534842 in newton iteration 1
#  error 0.0013420135643379824 in newton iteration 2
#  error 1.4531735110530438e-06 in newton iteration 3
#  error 9.97656852292837e-15 in newton iteration 4
# B(0.39): (-0.0011711006516928095, 0.02543840509036931, 0.015206407505987384)
#
# Implicit Euler Iteration: 79
#
#  error 257.9801637421894 in newton iteration 1
#  error 0.009605441348892742 in newton iteration 2
#  error 3.4243463542203562e-06 in newton iteration 3
#  error 2.411823715016079e-10 in newton iteration 4
# B(0.395): (-0.00011771724583407404, 0.0022805286337839723, 0.0006878386089252266)
#
# Implicit Euler Iteration: 80
#
#  error 81.74918921424198 in newton iteration 1
#  error 0.049405556862046465 in newton iteration 2
#  error 1.8848273593148718e-06 in newton iteration 3
#  error 4.412889071326705e-13 in newton iteration 4
# B(0.4): (0.001018292072593482, -0.022486005866567484, -0.01452385052334428)
#
# Implicit Euler Iteration: 81
#
#  error 50.67608117947128 in newton iteration 1
#  error 4.370335109164732e-06 in newton iteration 2
#  error 7.27554746859672e-14 in newton iteration 3
# B(0.405): (0.0013339602490833435, -0.029335392452428666, -0.018409604484484525)
#
# Implicit Euler Iteration: 82
#
#  error 245.61903928935405 in newton iteration 1
#  error 0.006763612198656602 in newton iteration 2
#  error 4.051439756644011e-06 in newton iteration 3
#  error 5.015936398169638e-10 in newton iteration 4
# B(0.41000000000000003): (0.0005538549352791535, -0.011499845176024396, -0.007059407961692432)
#
# Implicit Euler Iteration: 83
#
#  error 157.6073058468268 in newton iteration 1
#  error 0.023929991859187514 in newton iteration 2
#  error 2.4675078332702835e-07 in newton iteration 3
#  error 1.443718652374262e-14 in newton iteration 4
# B(0.41500000000000004): (-0.0006637287783751659, 0.014886101504375642, 0.009268849709610196)
#
# Implicit Euler Iteration: 84
#
#  error 16.846852641626484 in newton iteration 1
#  error 0.001255535919971314 in newton iteration 2
#  error 5.760772527560682e-06 in newton iteration 3
#  error 1.5922659732697807e-13 in newton iteration 4
# B(0.42): (-0.0013399940168824836, 0.02958239212297695, 0.018094632564990703)
#
# Implicit Euler Iteration: 85
#
#  error 191.95331786118857 in newton iteration 1
#  error 0.007855925429524846 in newton iteration 2
#  error 1.3939764467760196e-06 in newton iteration 3
#  error 7.910259139742572e-13 in newton iteration 4
# B(0.425): (-0.0009098496580515202, 0.01930525044185275, 0.011369910427393975)
#
# Implicit Euler Iteration: 86
#
#  error 224.45968455535723 in newton iteration 1
#  error 0.037810582754879425 in newton iteration 2
#  error 4.079672698377149e-06 in newton iteration 3
#  error 5.474735248945785e-12 in newton iteration 4
# B(0.43): (0.00026880420728261824, -0.006219673356388086, -0.004474734908150957)
#
# Implicit Euler Iteration: 87
#
#  error 28.692266811284657 in newton iteration 1
#  error 0.010514988597859107 in newton iteration 2
#  error 5.052931266495833e-06 in newton iteration 3
#  error 2.0627009801577725e-13 in newton iteration 4
# B(0.435): (0.0012238763517882735, -0.02711774199724672, -0.01721681005391727)
#
# Implicit Euler Iteration: 88
#
#  error 117.54282198210554 in newton iteration 1
#  error 0.0013394131934279649 in newton iteration 2
#  error 1.4717388635655862e-06 in newton iteration 3
#  error 1.029676902149094e-14 in newton iteration 4
# B(0.44): (0.00116693257894564, -0.025426335645988733, -0.015797515987525646)
#
# Implicit Euler Iteration: 89
#
#  error 257.98134721790126 in newton iteration 1
#  error 0.01014729845683314 in newton iteration 2
#  error 3.7958749111286174e-06 in newton iteration 3
#  error 2.3740216392127454e-10 in newton iteration 4
# B(0.445): (0.00011526992719817587, -0.0022792042605640703, -0.0012847601666688903)
#
# Implicit Euler Iteration: 90
#
#  error 81.69558409202172 in newton iteration 1
#  error 0.0522346176965262 in newton iteration 2
#  error 1.904064792421359e-06 in newton iteration 3
#  error 3.827960444089486e-13 in newton iteration 4
# B(0.45): (-0.0010198153884288202, 0.022490638907548453, 0.013935410105670442)
#
# Implicit Euler Iteration: 91
#
#  error 50.677833764946485 in newton iteration 1
#  error 4.243052563043332e-06 in newton iteration 2
#  error 9.78816202139899e-13 in newton iteration 3
# B(0.455): (-0.0013365206184002088, 0.029343746566134487, 0.017829320780690397)
#
# Implicit Euler Iteration: 92
#
#  error 245.61574791980811 in newton iteration 1
#  error 0.0067577705909181215 in newton iteration 2
#  error 4.013633558049033e-06 in newton iteration 3
#  error 2.849163926719817e-10 in newton iteration 4
# B(0.46): (-0.0005578503601190824, 0.011506884594139398, 0.006478346146060169)
#
# Implicit Euler Iteration: 93
#
#  error 157.61872087129876 in newton iteration 1
#  error 0.024652274986386107 in newton iteration 2
#  error 2.767152553460599e-07 in newton iteration 3
#  error 1.6864616289022397e-14 in newton iteration 4
# B(0.465): (0.000661302529680474, -0.014880755248226856, -0.009848698525420543)
#
# Implicit Euler Iteration: 94
#
#  error 16.84456860232929 in newton iteration 1
#  error 0.0012517674405552925 in newton iteration 2
#  error 5.76813086144415e-06 in newton iteration 3
#  error 1.368753783349449e-13 in newton iteration 4
# B(0.47000000000000003): (0.0013376913679271573, -0.029576241998540313, -0.018669464644036373)
#
# Implicit Euler Iteration: 95
#
#  error 191.95413541895826 in newton iteration 1
#  error 0.007875374968968342 in newton iteration 2
#  error 1.4000144031629316e-06 in newton iteration 3
#  error 1.0184447310880551e-12 in newton iteration 4
# B(0.47500000000000003): (0.0009085685349774693, -0.01930014087967852, -0.011943179344623283)
#
# Implicit Euler Iteration: 96
#
#  error 224.45847424217177 in newton iteration 1
#  error 0.037919836404155714 in newton iteration 2
#  error 3.752864453960653e-06 in newton iteration 3
#  error 3.960353867640241e-12 in newton iteration 4
# B(0.48): (-0.0002650164207678917, 0.006211343712474149, 0.0038927429074591276)
#
# Implicit Euler Iteration: 97
#
#  error 28.706092503596665 in newton iteration 1
#  error 0.009812155978349156 in newton iteration 2
#  error 4.999209060348712e-06 in newton iteration 3
#  error 2.0359199951636302e-13 in newton iteration 4
# B(0.485): (-0.0012203987417807505, 0.027113485979051204, 0.01664381433077582)
#
# Implicit Euler Iteration: 98
#
#  error 117.54266592262472 in newton iteration 1
#  error 0.0013423283118008766 in newton iteration 2
#  error 1.4541996075042882e-06 in newton iteration 3
#  error 1.0073149079303068e-14 in newton iteration 4
# B(0.49): (-0.0011639445123520623, 0.025426089902974645, 0.01523386576289339)
#
# Implicit Euler Iteration: 99
#
#  error 257.98020043932155 in newton iteration 1
#  error 0.009651216138419719 in newton iteration 2
#  error 3.511365644790659e-06 in newton iteration 3
#  error 2.424706685749286e-10 in newton iteration 4
# B(0.495): (-0.00011073305765455097, 0.002270057186740811, 0.0007161700361551143)

# %%
# %matplotlib
from matplotlib import pyplot as plt
from mpl_toolkits import mplot3d

fig = plt.figure()
axis = plt.axes()

x_val = np.arange(0, MAX_STEPS*dt, dt)
plt.plot(x_val, plot_data['B'][0], label='x')
plt.plot(x_val, plot_data['B'][1], label='y')
plt.plot(x_val, plot_data['B'][2], label='z')
plt.title("B(0.35,0,0)")
plt.legend()
# Out:
# Using matplotlib backend: Qt5Agg
# 0.025426089902974645
