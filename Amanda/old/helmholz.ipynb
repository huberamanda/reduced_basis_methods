# %%
from ngsolve import *
from netgen.geom2d import unit_square
import numpy as np
import scipy.sparse as sparse


class ReducedBasis:

    def __init__(self):

        self.setSpace(np.pi, 0.4, 0.6)    
        self.setInterval(0, 5)

    def reset(self):
        
        self.V = None
        self.K_red = None
        self.M_red = None
        self.P_red = None
        self.sol = []
        self.norm_of_solutions_red = [] 
        self.norm_of_solutions_orig = [] # l2 norm 
        self.residual = []
        self.dim_orig= len(self.gfu.vec)# dim of original space
        self.dim_red  = None
        self.__snapshots_updated = True
        self.__snapshots = []
        self.indices = []
        self.__first_draw = True
        self.__drawmode = 'default'
        
    def setDrawmode(self, mode):
        allowed_modes = ['webgui', 'default']
        
        if mode in allowed_modes:
            self.__drawmode = mode
        else:
            self.__drawmode = 'default'
        self.__first_draw = True
        

    def setSpace(self, a, x_0, y_0, rb='dirichlet'):
        ## generate mesh
        geo = netgen.geom2d.SplineGeometry()

        p1 = geo.AppendPoint (0,0)
        p2 = geo.AppendPoint (a,0)
        p3 = geo.AppendPoint (a,a)
        p4 = geo.AppendPoint (0,a)

        geo.Append (["line", p1, p2], bc = "bottom")
        geo.Append (["line", p2, p3], bc = "right")
        geo.Append (["line", p3, p4], bc = "top")
        geo.Append (["line", p4, p1], bc = "left")

        self.mesh = Mesh(geo.GenerateMesh(maxh=0.1))

        if rb == 'dirichlet':
            self.fes = H1(self.mesh, order=5, dirichlet='top|bottom|left|right')
        else:
            self.fes = H1(self.mesh, order=5)
        u,v =self.fes.TnT()

        factor = 25

        func = exp(-factor*((x-x_0)**2 + (y-y_0)**2))

        self.f = LinearForm(self.fes)
        self.f += func * v * dx
        self.f.Assemble()

        self.omega = Parameter(0)
        self.a = BilinearForm(self.fes)
        self.a += (grad(u)*grad(v) - self.omega*self.omega *u*v) * dx
        self.a.Assemble()

        self.gfu = GridFunction(self.fes)
        self.drawu = GridFunction(self.fes)
        

        self.k_blf = BilinearForm(self.fes)
        self.k_blf += grad(u)*grad(v)*dx
        self.k_blf.Assemble()
        rows,cols,vals = self.k_blf.mat.COO()
        self.K_orig = sparse.csr_matrix((vals,(rows,cols)))

        self.m_blf = BilinearForm(self.fes)
        self.m_blf += u*v * dx
        self.m_blf.Assemble()
        rows,cols,vals = self.m_blf.mat.COO()
        self.M_orig = sparse.csr_matrix((vals,(rows,cols)))

        self.reset()


    def setInterval(self, beginning, end):
        self.beginning = beginning
        self.end = end

        self.reset()
        
    def save(self, out_dir):
        
        print("save in folder {}", out_dir)
        
        changeable = [self.V, self.K_red, self.M_red, self.P_red, self.sol, self.norm_of_solutions_red,                               self.norm_of_solutions_orig, self.residual, self.beginning, self.end, self.dim_orig, self.dim_red, 
         self.__snapshots, self.__snapshots_updated, self.indices]

        for j in range(len(changeable)):
            np.save(out_dir+str(j), changeable[j], allow_pickle=True)
            
    def load(self, in_dir):
        
        print("load from folder {}", in_dir)

        ending = ".npy"
        self.V = np.load(in_dir+str(1)+ending, allow_pickle=True)
        self.K_red = np.load(in_dir+str(2)+ending, allow_pickle=True)
        self.M_red = np.load(in_dir+str(3)+ending, allow_pickle=True)
        self.P_red = np.load(in_dir+str(4)+ending, allow_pickle=True)
        self.sol = np.load(in_dir+str(5)+ending).tolist()
        self.norm_of_solutions_red = np.load(in_dir+str(6)+ending).tolist()
        self.norm_of_solutions_orig = np.load(in_dir+str(7)+ending).tolist()
        self.residual = np.load(in_dir+str(8)+ending).tolist()
        self.beginning = np.load(in_dir+str(9)+ending)
        self.end = np.load(in_dir+str(10)+ending)
        self.dim_orig= np.load(in_dir+str(11)+ending)
        self.dim_red  = np.load(in_dir+str(12)+ending)
        self.__snapshots = np.load(in_dir+str(13)+ending)
        self.__snapshots_updated = np.load(in_dir+str(14)+ending)
        self.indices = np.load(in_dir+str(15)+ending).tolist()
        
        
    def setSnapshots(self, new_snapshots, reset = False):
        ## TODO: check format of snapshots
        if len(self.__snapshots) > 0 and not reset:
            print("append snapshots with {}".format(new_snapshots))
            self.__snapshots = np.append(self.__snapshots, np.array(new_snapshots))
        else:
            print("set snapshots and reset basis")
            self.__snapshots = np.array(new_snapshots)
            self.V = None
        self.__snapshots_updated = True
        tmp = self.__snapshots
        zip_to_sort = list(zip(tmp, range(len(tmp))))
        sorted_zip = sorted(zip_to_sort, key=lambda x: x[0], reverse=False)
        self.indices = [tup[1] for tup in sorted_zip]
    
    def getSnapshots(self, sorted = True):
        return self.__snapshots[self.indices]
          
                
    def __computeRB(self):

        print("compute Reduced Basis")


        if len(self.__snapshots) == 0:
            print(""" no snapshots given, please call 'instance.setSnapshots' first""")
            return
        
        _visual = False
        if _visual:
            Draw(self.gfu)

        self.dim_red = len(self.__snapshots)
        V_tmp = np.zeros((self.dim_orig, self.dim_red))

        try: 
            existing_basis_len = self.V.shape[1]
            V_tmp[:,0:existing_basis_len] = self.V
            print("extending basis")
        except:
            existing_basis_len = 0


        for n in range(0+existing_basis_len, self.dim_red):
            _omega = self.__snapshots[n]
            ## compute FEM solution for parameter _omega
            self.omega.Set(_omega)
            self.a.Assemble()
            self.gfu.vec.data = self.a.mat.Inverse(self.fes.FreeDofs(), inverse="sparsecholesky") * self.f.vec
            nof = Integrate(self.gfu*self.gfu, self.mesh)
            self.norm_of_solutions_orig += [nof]
            V_tmp[:,n] = np.array(self.gfu.vec.data) 
            self.sol += [self.gfu.vec]

            if _visual:
                Redraw()
                input("norm of solution {}: {}".format(_omega, nof))
                
        try:
            q, r = np.linalg.qr(V_tmp)
            self.V = V_tmp.dot(np.linalg.inv(r))
        except:
            print("Matrix is singular")

        self.K_red = np.transpose(self.V).dot(self.K_orig.dot(self.V))
        self.M_red = np.transpose(self.V).dot(self.M_orig.dot(self.V))
        self.P_red = np.transpose(self.V).dot(self.f.vec.data)
        
        self.__snapshots_updated = False
        print("finished computing Reduced Basis")


    def computeValues(self, param, residual=True, norm=True, *args, **kwargs):

        if self.__snapshots_updated:
            self.__computeRB()
        
        self.norm_of_solutions_red = []
        self.residual = []

        ured = GridFunction(self.fes)
        tmp = GridFunction(self.fes)

        j = 0
        norm_diff = []
        for _omega in param:
            if 'time' in args:
                t3 = Timer("t3")
                t3.Start()
            Ainv = np.linalg.inv(self.K_red-_omega*_omega*self.M_red)

            red_sol_vec = np.matmul(Ainv, self.P_red)

            ured.vec.FV().NumPy()[:] = self.V.dot(red_sol_vec)[:]
            if 'time' in args:
                t3.Stop()
            
            if norm:
                
                nof = Integrate(ured*ured, self.mesh)
                self.norm_of_solutions_red += [nof]
            
            if residual:
                ## TODO: efficient version 
                # print("compute Residual")
                
                ## TODO: A in sparse
                
                if 'numpy' in args:
                    if 'timer' in args:
                        t1 = Timer("t1")
                        t1a = Timer("t1a")
                        t1b = Timer("t1b")
                        t1.Start()
                        t1a.Start()
                    
                    tmp = self.K_orig.dot(np.array(ured.vec.data)
                        ) - _omega*_omega*self.M_orig.dot(np.array(ured.vec.data)
                        ) - self.f.vec.data

                    if 'timer' in args:
                        t1a.Stop()
                        t1b.Start()

                    res2 = np.linalg.norm(tmp[self.fes.FreeDofs()])

                    if 'timer' in args:
                        t1b.Stop()
                        t1.Stop()

                        t2.AddFlops(2*self.k_blf.mat.nze)
                        t2.Start()
                                
                
                ngs_temp = self.k_blf.mat.CreateColVector()
                ngs_temp.data = self.k_blf.mat*ured.vec - _omega*_omega*self.m_blf.mat*ured.vec - self.f.vec
                
                ngs_temp2 = self.k_blf.mat.CreateColVector()
                ngs_temp2.data = Projector(self.fes.FreeDofs(), True)*ngs_temp

                if 'timer' in args:
                    t2.Stop()
                
                res = Norm(ngs_temp2)
                
                self.residual += [res]

            j += 1


    def draw(self, omega):
        
        if self.__snapshots_updated:
            self.__computeRB()
        
        if self.__drawmode == 'webgui':
            from ngsolve.webgui import Draw

        elif self.__drawmode == 'default':
            import netgen.gui
            from ngsolve import Draw
            if self.__first_draw:
                Draw(self.drawu)
                self.__first_draw = False
        else: 
            print("unknown drawmode use instance.setDrawmode")
            return
            self.__first_draw = False

        ## TODO: solve lgs
        Ainv = np.linalg.inv(self.K_red-omega*omega*self.M_red)
        red_sol_vec = np.matmul(Ainv, self.P_red)
        
        self.drawu.vec.FV().NumPy()[:] = self.V.dot(red_sol_vec)[:]
        
        if self.__drawmode == 'webgui':
            if self.__first_draw:
                self.scene = Draw(self.drawu, self.mesh, websocket=True)
                self.__first_draw = False
            self.scene.Redraw()
        else:
            Redraw()

# %%
RBinst = ReducedBasis()
RBinst.setInterval(0,5)
params = np.arange(5)
RBinst.setSnapshots(params, reset=True)
random_omegas = np.sort(np.append(np.random.uniform(RBinst.beginning, RBinst.end, 50), params))

with TaskManager(int(1e8)):
    t2 = Timer("t2")
    RBinst.computeValues(random_omegas, norm=False)
# Out:
# set snapshots and reset basis
# compute Reduced Basis
# finished computing Reduced Basis

# %%
for t in Timers():
    print(t)
# Out:
# {'name': 'BaseVector::L2Norm', 'time': 0.0008662342877155183, 'counts': 55, 'flops': 1570855.0, 'Gflop/s': 1.8134297178916192}
# {'name': 'Projector::Project', 'time': 0.001841901473807022, 'counts': 55, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'BaseVector::Add', 'time': 0.0026143451010967374, 'counts': 55, 'flops': 1570855.0, 'Gflop/s': 0.6008598479753169}
# {'name': 'ScaleMatrix::MultAdd', 'time': 0.028019749479090732, 'counts': 55, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'SparseMatrix::MultAdd', 'time': 0.05914853088936493, 'counts': 110, 'flops': 96571310.0, 'Gflop/s': 1.6326916078546898}
# {'name': 'gfu', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'gfu', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'Integrate CF', 'time': 0.0029351549745893855, 'counts': 5, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'SparseCholesky<d,d,d>::MultAdd fac2', 'time': 0.004533238286163277, 'counts': 5, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'SparseCholesky<d,d,d>::MultAdd fac1', 'time': 0.005284019819091783, 'counts': 5, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'SparseCholesky<d,d,d>::MultAdd', 'time': 0.010261189417698387, 'counts': 5, 'flops': 11359310.0, 'Gflop/s': 1.107016890303924}
# {'name': 'SparseCholesky::Factor SPD - dense cholesky', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'SparseCholesky::Factor SPD - setup dense cholesky', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'SparseCholesky::Factor SPD', 'time': 0.08064114833272454, 'counts': 5, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'SparseCholesky - fill factor', 'time': 0.0187330858324945, 'counts': 5, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'BaseVector::Set', 'time': 0.0053844838540301875, 'counts': 60, 'flops': 5960460.0, 'Gflop/s': 1.1069696114955765}
# {'name': 'MDO::EliminateMaster', 'time': 0.2671336347107119, 'counts': 22580, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'MinimumDegreeOrdering::Order', 'time': 0.2871218577038959, 'counts': 5, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'MinimumDegreeOrdering::ctor', 'time': 0.0004035624602205997, 'counts': 5, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'SparseCholesky - allocate', 'time': 0.053778373797784246, 'counts': 5, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'SparseCholesky - total', 'time': 0.5682022770757296, 'counts': 5, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 't2', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'biform_from_py low-order', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'biform_from_py', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'biform_from_py low-order', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'biform_from_py', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'gfu', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'gfu', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'SparseMatrix::AddElementMatrix', 'time': 0.059396868177451004, 'counts': 0, 'flops': 5085000.0, 'Gflop/s': 0.08561057436241114}
# {'name': 'SymbolicBFI::CalcElementMatrixAddddd', 'time': 0.12322570911625792, 'counts': 0, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'calc elmats', 'time': 0.12860523930425924, 'counts': 0, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'SparseMatrix::SetZero (taskhandler)', 'time': 0.012027188377081846, 'counts': 16, 'flops': 7088144.0, 'Gflop/s': 0.5893433924679073}
# {'name': 'Matrix assembling co dim 2', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'Matrix assembling bound', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'Matrix assembling vol', 'time': 0.09596048979310301, 'counts': 16, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'Matrix assembling finalize matrix', 'time': 0.0009012135935606173, 'counts': 16, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'Matrix assembling initializing', 'time': 0.012637658676927071, 'counts': 16, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'Matrix assembling check integrators', 'time': 0.001733447006487066, 'counts': 16, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'Matrix assembling', 'time': 0.11127834699203046, 'counts': 16, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'MatrixGraph - CalcBalancing', 'time': 0.0007512467492042022, 'counts': 17, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'MatrixGraph - prefix', 'time': 0.00025764700612906693, 'counts': 6, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'MatrixGraph - build dof2el table', 'time': 0.0029616823239698997, 'counts': 6, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'MatrixGraph', 'time': 0.04440624591267621, 'counts': 6, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'BilinearForm::GetGraph', 'time': 0.048922724808880325, 'counts': 6, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'biform_from_py low-order', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'biform_from_py', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'Vector assembling 3', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'Vector assembling 2', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'Vector assembling 1', 'time': 0.0008112158699131988, 'counts': 1, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'Vector assembling', 'time': 0.006208200433392378, 'counts': 1, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'S_BaseVector::SetScalar', 'time': 0.003809942490339709, 'counts': 76, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'lff_from_py', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'FESpace::FinalizeUpdate', 'time': 0.0006453620479785702, 'counts': 2, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'H1HighOrderFESpace::UpdateCouplingDofArray', 'time': 3.175602164920047e-05, 'counts': 1, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'H1HighOrderFESpace::UpdateDofTables', 'time': 3.667824192675319e-05, 'counts': 1, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'H1HighOrderFESpace::Update', 'time': 0.0003017043588233901, 'counts': 1, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'FESpace', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'FESpace', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'CalcIdentifiedFacets', 'time': 8.313762967722451e-06, 'counts': 1, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'MeshAccess::UpdateBuffers', 'time': 0.0003367870460630883, 'counts': 3, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'clusters', 'time': 0.00013551191007583942, 'counts': 1, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'topology::buildfaces', 'time': 0.0005054189792495246, 'counts': 1, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'topology::buildedges', 'time': 0.0009321372894920747, 'counts': 1, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'topology', 'time': 0.0016078892478340694, 'counts': 1, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'Build edges', 'time': 0.0006670832174224085, 'counts': 3, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'Combineimprove 2D start1', 'time': 0.0012481963659380106, 'counts': 3, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'Combineimprove 2D start', 'time': 0.001294252249775888, 'counts': 3, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'Combineimprove 2D', 'time': 0.009926073880000018, 'counts': 3, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'MeshSmooting 2D - loop', 'time': 0.03125694216475548, 'counts': 6, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'ComputeColoring - netgen::MeshOptimize2d::ImproveMesh(netgen::MeshingParameters const&)::{lambda(int)#3}', 'time': 0.00012854368760619212, 'counts': 6, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'MeshSmoothing 2D', 'time': 0.03263108185975185, 'counts': 6, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'Mesh::CreatePoint2SurfaceElementTable', 'time': 0.0019450117559735105, 'counts': 12, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'EdgeSwapping 2D start', 'time': 0.0021703030228734824, 'counts': 3, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'EdgeSwapping-Find neighbors', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'EdgeSwapping (2D)', 'time': 0.00231669002271385, 'counts': 3, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'Mesh::LinkSurfaceElements', 'time': 4.4061044886987374e-05, 'counts': 8, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'Mesh::Compress', 'time': 0.0005157080652926259, 'counts': 8, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'Mesh::CalcSurfacesOfNode - surfelementht', 'time': 4.056137369736433e-07, 'counts': 13, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'Mesh::CalcSurfacesOfNode - surf on node', 'time': 4.852596073026681e-07, 'counts': 13, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'Mesh::CalcSurfacesOfNode', 'time': 8.705768337447824e-05, 'counts': 13, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'optimize2d', 'time': 0.048107841009283225, 'counts': 2, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'meshing2::ApplyRules 1', 'time': 0.004638751658298106, 'counts': 1394, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'adfront2::GetLocals', 'time': 0.002976511752077852, 'counts': 1394, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'surfacemeshing mainloop', 'time': 0.015646142180196936, 'counts': 1, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'GetSurfaceElementsOfFace', 'time': 0.0001595143271300951, 'counts': 4, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'surface meshing start 3', 'time': 1.1967978793149499e-06, 'counts': 1, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'surface meshing start 2', 'time': 4.69435924455842e-08, 'counts': 1, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'surface meshing start 1', 'time': 0.00018164532995966614, 'counts': 1, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'surface meshing3', 'time': 0.004388301263127787, 'counts': 1394, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'surface meshing2', 'time': 0.010990903299284637, 'counts': 1394, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'surface meshing1', 'time': 0.015630805866781797, 'counts': 1394, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'surface meshing', 'time': 0.015856746959590672, 'counts': 1, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'Parsing rules', 'time': 0.00036498748617660694, 'counts': 1, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'Mesing2::Meshing2', 'time': 0.0008792250038766677, 'counts': 1, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'Mesh::CalcLocalH', 'time': 4.213319286014905e-05, 'counts': 1, 'flops': 0.0, 'Gflop/s': 0.0}
# {'name': 'NewtonSolver.Solve', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'PreconditionedRichardson', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'MinRes', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'QMR', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'CGSolver.Solve', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'H1FESpace::GetFE', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'AddABt-double-complex, sym', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'AddABt-complex-double', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}
# {'name': 'AddABt-double-complex', 'time': 0.0, 'counts': 0, 'flops': 0.0, 'Gflop/s': nan}

# %%
help(TaskManager)
## HI
# Out:
# Help on class TaskManager in module pyngcore:
#
# class TaskManager(pybind11_builtins.pybind11_object)
#  |  Method resolution order:
#  |      TaskManager
#  |      pybind11_builtins.pybind11_object
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __enter__(...)
#  |      __enter__(self: pyngcore.TaskManager) -> None
#  |
#  |  __exit__(...)
#  |      __exit__(self: pyngcore.TaskManager, arg0: object, arg1: object, arg2: object) -> None
#  |
#  |  __init__(...)
#  |      __init__(*args, **kwargs)
#  |      Overloaded function.
#  |
#  |      1. __init__(self: pyngcore.TaskManager) -> None
#  |
#  |      2. __init__(self: pyngcore.TaskManager, pajetrace: int) -> None
#  |
#  |      Run paje-tracer, specify buffersize in bytes
#  |
#  |  __timing__(...)
#  |      __timing__() -> std::__cxx11::list<std::tuple<std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> >, double>, std::allocator<std::tuple<std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> >, double> > >
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from pybind11_builtins.pybind11_object:
#  |
#  |  __new__(*args, **kwargs) from pybind11_builtins.pybind11_type
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
RBinst = ReducedBasis()
RBinst.setInterval(0,5)
params = np.arange(5)
RBinst.setSnapshots(params, reset=True)
random_omegas = np.sort(np.append(np.random.uniform(RBinst.beginning, RBinst.end, 200), params))

import cProfile, pstats, io

cp = cProfile.Profile()
cp.enable()

RBinst.computeValues(random_omegas)
cp.disable()

s = io.StringIO()
sortby = 'cumulative'
ps = pstats.Stats(cp, stream=s).sort_stats(sortby)
ps.print_stats()
print(s.getvalue())
# Out:
# set snapshots and reset basis
# compute Reduced Basis
# finished computing Reduced Basis
#          5187 function calls (5185 primitive calls) in 2.835 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    2.835    1.417 /home/ams/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3293(run_code)
#         2    0.000    0.000    2.835    1.417 {built-in method builtins.exec}
#         1    0.000    0.000    2.835    2.835 <ipython-input-21-0f349f282590>:12(<module>)
#         1    0.980    0.980    2.835    2.835 <ipython-input-19-7d8ba0996dfc>:206(computeValues)
#         1    0.680    0.680    0.952    0.952 <ipython-input-19-7d8ba0996dfc>:153(__computeRB)
#       210    0.719    0.003    0.719    0.003 {built-in method ngsolve.comp.Integrate}
#       209    0.213    0.001    0.213    0.001 {method 'dot' of 'numpy.ndarray' objects}
#       213    0.154    0.001    0.154    0.001 {built-in method numpy.array}
#   212/210    0.001    0.000    0.055    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#       206    0.001    0.000    0.054    0.000 <__array_function__ internals>:2(inv)
#       206    0.045    0.000    0.052    0.000 /home/ams/.local/lib/python3.6/site-packages/numpy/linalg/linalg.py:482(inv)
#         2    0.000    0.000    0.020    0.010 /home/ams/.local/lib/python3.6/site-packages/scipy/sparse/base.py:350(dot)
#         2    0.000    0.000    0.020    0.010 /home/ams/.local/lib/python3.6/site-packages/scipy/sparse/base.py:457(__mul__)
#         2    0.000    0.000    0.020    0.010 /home/ams/.local/lib/python3.6/site-packages/scipy/sparse/compressed.py:477(_mul_multivector)
#         2    0.019    0.010    0.019    0.010 {built-in method scipy.sparse._sparsetools.csr_matvecs}
#       205    0.013    0.000    0.013    0.000 {built-in method ngsolve.bla.Norm}
#       207    0.001    0.000    0.002    0.000 /home/ams/.local/lib/python3.6/site-packages/numpy/linalg/linalg.py:144(_commonType)
#       207    0.001    0.000    0.002    0.000 /home/ams/.local/lib/python3.6/site-packages/numpy/linalg/linalg.py:116(_makearray)
#         1    0.000    0.000    0.001    0.001 <__array_function__ internals>:2(qr)
#         1    0.000    0.000    0.001    0.001 /home/ams/.local/lib/python3.6/site-packages/numpy/linalg/linalg.py:765(qr)
#       207    0.001    0.000    0.001    0.000 {method 'astype' of 'numpy.ndarray' objects}
#       206    0.001    0.000    0.001    0.000 /home/ams/.local/lib/python3.6/site-packages/numpy/linalg/linalg.py:111(get_linalg_error_extobj)
#       207    0.000    0.000    0.001    0.000 /home/ams/.local/lib/python3.6/site-packages/numpy/core/_asarray.py:16(asarray)
#       206    0.001    0.000    0.001    0.000 /home/ams/.local/lib/python3.6/site-packages/numpy/linalg/linalg.py:203(_assert_stacked_2d)
#       206    0.001    0.000    0.001    0.000 /home/ams/.local/lib/python3.6/site-packages/numpy/linalg/linalg.py:209(_assert_stacked_square)
#         3    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/numpy/linalg/linalg.py:185(_fastCopyAndTranspose)
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath._fastCopyAndTranspose}
#       415    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/numpy/linalg/linalg.py:121(isComplexType)
#         9    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#       207    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/numpy/linalg/linalg.py:134(_realType)
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.linalg.lapack_lite.dgeqrf}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.linalg.lapack_lite.dorgqr}
#       622    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#       216    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         4    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/ipykernel/iostream.py:384(write)
#       206    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/numpy/linalg/linalg.py:478(_unary_dispatcher)
#       209    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         5    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/ipykernel/iostream.py:197(schedule)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(triu)
#         5    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/zmq/sugar/socket.py:342(send)
#       208    0.000    0.000    0.000    0.000 {method '__array_prepare__' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.6/codeop.py:132(__call__)
#         1    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/numpy/lib/twodim_base.py:441(triu)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(transpose)
#         1    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/numpy/lib/twodim_base.py:348(tri)
#         3    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:604(transpose)
#         5    0.000    0.000    0.000    0.000 /usr/lib/python3.6/threading.py:1104(is_alive)
#         3    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:55(_wrapfunc)
#         4    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/ipykernel/iostream.py:322(_schedule_flush)
#         1    0.000    0.000    0.000    0.000 {method 'outer' of 'numpy.ufunc' objects}
#         4    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/ipykernel/iostream.py:309(_is_master_process)
#         5    0.000    0.000    0.000    0.000 /usr/lib/python3.6/threading.py:1062(_wait_for_tstate_lock)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.6/contextlib.py:157(helper)
#         2    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/numpy/lib/twodim_base.py:33(_min_int)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.6/contextlib.py:59(__init__)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.6/contextlib.py:79(__enter__)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.6/contextlib.py:85(__exit__)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(where)
#         4    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/IPython/core/compilerop.py:138(extra_flags)
#         4    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:117(<lambda>)
#         5    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/scipy/sparse/sputils.py:56(upcast_char)
#         1    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/numpy/linalg/linalg.py:173(_to_native_byte_order)
#         2    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/IPython/core/hooks.py:103(__call__)
#         1    0.000    0.000    0.000    0.000 <ipython-input-21-0f349f282590>:13(<module>)
#         4    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         3    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         5    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/ipykernel/iostream.py:93(_event_pipe)
#         2    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/traitlets/traitlets.py:545(__get__)
#         1    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/numpy/core/_asarray.py:88(asanyarray)
#         2    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/IPython/utils/ipstruct.py:125(__getattr__)
#         5    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/scipy/sparse/data.py:25(_get_dtype)
#         1    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/numpy/linalg/linalg.py:197(_assert_2d)
#         2    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/numpy/core/getlimits.py:508(min)
#         2    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/traitlets/traitlets.py:526(get)
#         5    0.000    0.000    0.000    0.000 /usr/lib/python3.6/threading.py:506(is_set)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         4    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/scipy/sparse/base.py:84(get_shape)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#         2    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/numpy/core/getlimits.py:521(max)
#         3    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:600(_transpose_dispatcher)
#         2    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:1276(user_global_ns)
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/numpy/linalg/linalg.py:761(_qr_dispatcher)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3235(compare)
#         1    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/numpy/lib/twodim_base.py:398(_trilu_dispatcher)
#         1    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/numpy/core/multiarray.py:312(where)
#         2    0.000    0.000    0.000    0.000 /home/ams/.local/lib/python3.6/site-packages/IPython/core/hooks.py:168(pre_run_code_hook)

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets


RBinst = ReducedBasis()
RBinst.setInterval(0,5)
params = np.array(range(20))
RBinst.setSnapshots(params)

RBinst.setDrawmode("webgui")

# RBinst.draw(3)
f = lambda x: RBinst.draw(x)
interact(f, x=widgets.FloatSlider(min=RBinst.beginning, max=RBinst.end, step=0.05, value=3))
# Out:
# set snapshots and reset basis
# compute Reduced Basis
# finished computing Reduced Basis
# NGSWebGuiWidget(render_data={'ngsolve_version': '6.2.2004-92-gb58c18ee', 'mesh_dim': 2, 'order2d': 2, 'order3d…

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()                      
ax.plot(random_omegas, newRBinst.norm_of_solutions_red, '-', label = "norm")

#ax.plot(newRBinst.getSnapshots(), residuals_snapshots[i][newindices], '.r', label = "residual snapshot")
ax.set_xlabel("omega")
ax.set_ylabel('norm')
plt.semilogy()
ax.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9e682ead9873> in <module>
#       1 import matplotlib.pyplot as plt
#       2 fig, ax = plt.subplots()
# ----> 3 ax.plot(random_omegas, newRBinst.norm_of_solutions_red, '-', label = "norm")
#       4
#       5 #ax.plot(newRBinst.getSnapshots(), residuals_snapshots[i][newindices], '.r', label = "residual snapshot")
#
# NameError: name 'random_omegas' is not defined

# %%
import matplotlib.pyplot as plt
import os

fig, ax = plt.subplots()
out_dir = os.getcwd()+"/output/"
try:
    os.mkdir(path+out_dir)
except:
    print('no dir created')

RBinst = ReducedBasis()

beginning = RBinst.beginning
end= RBinst.end
eigenvalues = []
for j in range(beginning, end+1):
    for i in range(beginning, end+1):
        tmp = (i*i+j*j)**(1/2)
        if tmp <= end: eigenvalues += [tmp]
# print(eigenvalues)

stepsize = 0.5
first_snapshot = np.arange(RBinst.beginning,RBinst.end, stepsize)
MAX_IT = 10
snapshots = [None]*MAX_IT
norms_snapshots = [None]*MAX_IT
norms_red = [None]*MAX_IT
residuals = [None]*MAX_IT
residuals_snapshots = [None]*MAX_IT
random_omegas = np.sort(np.append(np.random.uniform(RBinst.beginning, RBinst.end, 1000), first_snapshot))

snapshots[0] = np.array(first_snapshot)
RBinst.setSnapshots(first_snapshot, reset = True)
# indices = range(len(snapshots[0]))
for i in range(0,MAX_IT):
    print("i = {}".format(i))

    RBinst.computeValues(snapshots[i])
    norms_snapshots[i] = np.array(RBinst.norm_of_solutions_orig)
    residuals_snapshots[i]= np.array(RBinst.residual)
    
    RBinst.computeValues(random_omegas)
    norms_red[i] = np.array(RBinst.norm_of_solutions_red)
    residuals[i] = np.array(RBinst.residual)
    
    ## plot and save
    plt.cla()
    ax.plot(random_omegas, residuals[i], '-', label = "residual")
    ax.plot(snapshots[i][RBinst.indices], residuals_snapshots[i][RBinst.indices], '.r', label = "residual snapshot")
    ax.set_xlabel("omega")
    ax.set_ylabel('residual')
    ax.set_title("residual {}".format(i))
    plt.semilogy()
    ax.legend()
    plt.savefig(out_dir+"residual {}".format(i))
#     plt.plot()

    plt.cla()
    ax.plot(random_omegas, norms_red[i], '-', label = "norm")
    ax.plot(eigenvalues, np.ones(len(eigenvalues)), '.', label="eigenvalues")
    ax.set_xlabel("omega")
    ax.set_ylabel('norm of reduced solution')
    ax.set_title("norm reduced solution {}".format(i))
    plt.semilogy()
    # ax.legend()
    plt.savefig(out_dir+"norm_red {}".format(i))
#     plt.plot()

    plt.cla()
    ax.plot(snapshots[i][RBinst.indices], norms_snapshots[i][RBinst.indices], '-', label = "norm")
    ax.set_xlabel("omega")
    ax.set_ylabel('norm of snapshot solution')
    ax.set_title("norm snapshot solution {}".format(i))
    plt.semilogy()
    # ax.legend()
    plt.savefig(out_dir+"norm_snap {}".format(i))
#     plt.plot()
    

    if i < MAX_IT-1:
        
        ## sort by residual
        tmp = residuals[i]
        zip_to_sort = list(zip(tmp, range(len(tmp))))
        sorted_zip = sorted(zip_to_sort, key=lambda x: x[0], reverse=True)
        tmp_ind = [tup[1] for tup in sorted_zip]
        for j in range(len(RBinst.indices)):
            if not (random_omegas[tmp_ind[j]] in snapshots[i]):
                max_omega = random_omegas[tmp_ind[j]]
                snapshots[i+1] = np.append(snapshots[i], max_omega)
                RBinst.setSnapshots(max_omega)
                break

        # tmp = snapshots[i+1]
        # zip_to_sort = list(zip(tmp, range(len(tmp))))
        # sorted_zip = sorted(zip_to_sort, key=lambda x: x[0], reverse=False)
        # indices = [tup[1] for tup in sorted_zip]

print('finished')
# Out:
# no dir created
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-85b433d722ad> in <module>
#       9     print('no dir created')
#      10
# ---> 11 RBinst = ReducedBasis()
#      12
#      13 beginning = RBinst.beginning
#
# NameError: name 'ReducedBasis' is not defined

# %%
RBinst.save("./saved_RBinst_/")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-1401bf4cab53> in <module>
# ----> 1 RBinst.save("./saved_RBinst_/")
#
# NameError: name 'RBinst' is not defined

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()                      
ax.plot(random_omegas, newRBinst.norm_of_solutions_red, '-', label = "norm")

# ax.plot(snapshots[i][indices], residuals_snapshots[i][indices], '.r', label = "residual snapshot")
ax.set_xlabel("omega")
ax.set_ylabel('norm')
plt.semilogy()
ax.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-25c6e07168db> in <module>
#       1 import matplotlib.pyplot as plt
#       2 fig, ax = plt.subplots()
# ----> 3 ax.plot(random_omegas, newRBinst.norm_of_solutions_red, '-', label = "norm")
#       4
#       5 # ax.plot(snapshots[i][indices], residuals_snapshots[i][indices], '.r', label = "residual snapshot")
#
# NameError: name 'random_omegas' is not defined
