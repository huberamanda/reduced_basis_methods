# %%
from netgen import gui
from ngsolve import *
from netgen.geom2d import SplineGeometry
import scipy.sparse as sp
import numpy as np
from math import pi

from ngsolve.solvers import *

# %%
from netgen.geom2d import SplineGeometry
geo = SplineGeometry()
geo.AddRectangle( (0, 0), (2, 0.41), bcs = ("wall", "outlet", "wall", "inlet"))
geo.AddCircle ( (0.2, 0.2), r=0.05, leftdomain=0, rightdomain=1, bc="cyl")
mesh = Mesh( geo.GenerateMesh(maxh=0.08))
mesh.Curve(3)
Draw(mesh)

# %%
k = 3
nu = 0.001
dt = 0.001
V = VectorH1(mesh,order=k, dirichlet="wall|cyl|inlet")
Q = H1(mesh,order=2);
X = FESpace([V,Q])
(u,p), (v,q) = X.TnT()
a = BilinearForm(X)
a += (dt*InnerProduct(u,v) + nu*InnerProduct(grad(u),grad(v))+InnerProduct(grad(u)*u,v)
      -div(u)*q-div(v)*p)*dx

# %%
gfu = GridFunction(X)
velocity = gfu.components[0]
Draw(velocity,mesh,"u",sd=3)
Draw(gfu.components[1],mesh,"p",sd=3)
  

uin = CoefficientFunction((1.5*4*y*(0.41-y)/(0.41*0.41),0))
gfu.components[0].Set(uin, definedon=mesh.Boundaries("inlet"))

Redraw()

# %%
def SimpleNewtonSolve(gfu,a,tol=1e-13,maxits=25):
    res = gfu.vec.CreateVector()
    du = gfu.vec.CreateVector()
    fes = gfu.space
    for it in range(maxits):
        print ("Iteration {:3}  ".format(it),end="")
        a.Apply(gfu.vec, res)
        a.AssembleLinearization(gfu.vec)
        du.data = a.mat.Inverse(fes.FreeDofs()) * res
        gfu.vec.data -= du

        #stopping criteria
        stopcritval = sqrt(abs(InnerProduct(du,res)))
        print ("<A u",it,", A u",it,">_{-1}^0.5 = ", stopcritval)
        if stopcritval < tol:
            break

# %%
SimpleNewtonSolve(gfu,a)
Draw(gfu.components[1],mesh,"p")
Draw(gfu.components[0],mesh,"u")

# %%
#gfu.vec[:]=0
Newton(a,gfu,freedofs=gfu.space.FreeDofs(),maxit=100,maxerr=1e-11,inverse="umfpack",dampfactor=1,printing=True)

# %%
Draw(gfu.components[0],mesh,"u")
dt = 0.001
for i in range(1,10):
    dt = dt*i
    with TaskManager():
        a = BilinearForm(X)
        a += (dt*InnerProduct(u,v) + nu*InnerProduct(grad(u),grad(v))+InnerProduct(grad(u)*u,v)-div(u)*q-div(v)*p)*dx
        Newton(a,gfu,maxit=200,dampfactor=0.1)
    Redraw()
# Out:
# Newton iteration  0
# err =  0.46113970426599427
# Newton iteration  1
# err =  0.33382061059560086
# Newton iteration  2
# err =  0.13844401728455924
# Newton iteration  3
# err =  0.213767448206066
# Newton iteration  4
# err =  0.17752745294769814
# Newton iteration  5
# err =  0.10748098406641296
# Newton iteration  6
# err =  0.04793428040986027
# Newton iteration  7
# err =  0.01522285585602895
# Newton iteration  8
# err =  0.003126625987040763
# Newton iteration  9
# err =  0.00031623706641117287
# Newton iteration  10
# err =  2.1859584652797786e-08
# Newton iteration  11
# err =  1.2219742334305981e-15
# Newton iteration  0
# err =  0.00032136916451385003
# Newton iteration  1
# err =  0.00028922837619856914
# Newton iteration  2
# err =  0.00023137668356966906
# Newton iteration  3
# err =  0.00016195814645869283
# Newton iteration  4
# err =  9.7171433693381e-05
# Newton iteration  5
# err =  4.8584234677095344e-05
# Newton iteration  6
# err =  1.943327092750836e-05
# Newton iteration  7
# err =  5.829906385889374e-06
# Newton iteration  8
# err =  1.1659739912810143e-06
# Newton iteration  9
# err =  1.1659708987989285e-07
# Newton iteration  10
# err =  2.5991724478656744e-14
# Newton iteration  0
# err =  0.0012831195632562024
# Newton iteration  1
# err =  0.0011547463404004647
# Newton iteration  2
# err =  0.0009237017980515494
# Newton iteration  3
# err =  0.0006465036030096741
# Newton iteration  4
# err =  0.00038784739678624804
# Newton iteration  5
# err =  0.0001939001916655428
# Newton iteration  6
# err =  7.755336868511122e-05
# Newton iteration  7
# err =  2.3264822953244802e-05
# Newton iteration  8
# err =  4.652849076837315e-06
# Newton iteration  9
# err =  4.65280008846045e-07
# Newton iteration  10
# err =  4.085657887979905e-13
# Newton iteration  0
# err =  0.0057292229432600265
# Newton iteration  1
# err =  0.005155120186302847
# Newton iteration  2
# err =  0.004122255219194419
# Newton iteration  3
# err =  0.0028838791037171167
# Newton iteration  4
# err =  0.0017292627797454972
# Newton iteration  5
# err =  0.0008641738076947545
# Newton iteration  6
# err =  0.000345538940735141
# Newton iteration  7
# err =  0.00010363857901223264
# Newton iteration  8
# err =  2.072547104010716e-05
# Newton iteration  9
# err =  2.072452015241049e-06
# Newton iteration  10
# err =  7.883829995199611e-12
# Newton iteration  0
# err =  0.029419186826558325
# Newton iteration  1
# err =  0.02645161668645718
# Newton iteration  2
# err =  0.0211206249637625
# Newton iteration  3
# err =  0.014746187139078206
# Newton iteration  4
# err =  0.008823433353023501
# Newton iteration  5
# err =  0.004401226016937658
# Newton iteration  6
# err =  0.0017574990201100493
# Newton iteration  7
# err =  0.0005267226150369984
# Newton iteration  8
# err =  0.00010529358052414874
# Newton iteration  9
# err =  1.0527212799350269e-05
# Newton iteration  10
# err =  1.7454389502800557e-10
# Newton iteration  11
# err =  9.395047235378514e-16
# Newton iteration  0
# err =  0.15095511264595576
# Newton iteration  1
# err =  0.13576647023313942
# Newton iteration  2
# err =  0.10838366222444996
# Newton iteration  3
# err =  0.0755512822142381
# Newton iteration  4
# err =  0.045066482776900695
# Newton iteration  5
# err =  0.022398350339568017
# Newton iteration  6
# err =  0.008917459298233031
# Newton iteration  7
# err =  0.0026675991497277693
# Newton iteration  8
# err =  0.0005327754149128646
# Newton iteration  9
# err =  5.324632908173753e-05
# Newton iteration  10
# err =  2.126020539275674e-09
# Newton iteration  11
# err =  3.4024184300875624e-15
# Newton iteration  0
# err =  0.520294062643048
# Newton iteration  1
# err =  0.47050091608671485
# Newton iteration  2
# err =  0.379149840066986
# Newton iteration  3
# err =  0.26670922654355034
# Newton iteration  4
# err =  0.15986236865320952
# Newton iteration  5
# err =  0.07948420025053371
# Newton iteration  6
# err =  0.03159659615903866
# Newton iteration  7
# err =  0.009438032864741685
# Newton iteration  8
# err =  0.0018833980515371132
# Newton iteration  9
# err =  0.00018815938569678674
# Newton iteration  10
# err =  1.3411165620177185e-08
# Newton iteration  11
# err =  1.9762563993337068e-14
# Newton iteration  0
# err =  0.8790593951128973
# Newton iteration  1
# err =  0.7915837823958426
# Newton iteration  2
# err =  0.6335873696536578
# Newton iteration  3
# err =  0.44327144581421457
# Newton iteration  4
# err =  0.26542702898404924
# Newton iteration  5
# err =  0.1323459014233487
# Newton iteration  6
# err =  0.05280936686513282
# Newton iteration  7
# err =  0.015818034338017744
# Newton iteration  8
# err =  0.0031611495977601767
# Newton iteration  9
# err =  0.00031601195614332364
# Newton iteration  10
# err =  1.0451399081621667e-08
# Newton iteration  11
# err =  1.350122667154948e-13
# Newton iteration  0
# err =  0.8666776043524472
# Newton iteration  1
# err =  0.7799871256294019
# Newton iteration  2
# err =  0.623949666851505
# Newton iteration  3
# err =  0.436721368624024
# Newton iteration  4
# err =  0.2620012784630377
# Newton iteration  5
# err =  0.13098546913261686
# Newton iteration  6
# err =  0.052389533179268304
# Newton iteration  7
# err =  0.015716003890293824
# Newton iteration  8
# err =  0.0031431163643989143
# Newton iteration  9
# err =  0.0003143080618984259
# Newton iteration  10
# err =  1.1883343110971576e-09
# Newton iteration  11
# err =  6.332858499465737e-13
